# %% [markdown]
# # Finetuning Tinyllama on Elon Musk's Tweets using Axolotl
#
# This notebook demonstrates the utilization of the [axolotl](https://github.com/OpenAccess-AI-Collective/axolotl) tool to perform fine-tuning on the [Tinyllama](https://huggingface.co/TinyLlama/TinyLlama-1.1B-Chat-v1.0) model using the dataset of tweets authored by Elon Musk.
#
# Throughout this project, we employ Weight and Biases to monitor the fine-tuning process, ensuring that we can track and analyze the model's performance as it adapts to the specific tweet data.
#
# We use the following config file that can be found on github:
# https://github.com/Skower/mlpops/blob/d676a2755426f0f94ee03a3649ba8c6c6f2d1d4e/model-finetuning/TinyLlamusk.yml
#
# ```
# base_model: TinyLlama/TinyLlama-1.1B-Chat-v1.0
# base_model_config: TinyLlama/TinyLlama-1.1B-Chat-v1.0
# model_type: LlamaForCausalLM
# tokenizer_type: LlamaTokenizer
# is_llama_derived_model: true
# hub_model_id: TinyLlamusk
#
# load_in_8bit: false
# load_in_4bit: true
# strict: false
#
# datasets:
#     - path: lcama/elon-tweets
#     type: completion
# dataset_prepared_path: last_run_prepared
# val_set_size: 0.02
# output_dir: ./qlora-out
#
# adapter: qlora
# lora_model_dir:
#
# sequence_len: 2048
# sample_packing: true
#
# lora_r: 32
# lora_alpha: 16
# lora_dropout: 0.05
# lora_target_modules:
# lora_target_linear: true
# lora_fan_in_fan_out:
#
# wandb_project: axolotl-tinyllama
# wandb_entity:
# wandb_watch:
# wandb_run_id:
# wandb_log_model:
#
# gradient_accumulation_steps: 1
# micro_batch_size: 10
# num_epochs: 3
# optimizer: paged_adamw_32bit
# lr_scheduler: cosine
# learning_rate: 0.0002
#
# train_on_inputs: false
# group_by_length: false
# bf16: true
# fp16: false
# tf32: false
#
# gradient_checkpointing: true
# early_stopping_patience:
# resume_from_checkpoint:
# local_rank:
# logging_steps: 1
# xformers_attention:
# flash_attention: true
#
# warmup_steps: 100
# eval_steps: 0.01
# save_strategy: epoch
# save_steps:
# debug:
# deepspeed:
# weight_decay: 0.0
# fsdp:
# fsdp_config:
# special_tokens:
#     bos_token: "<s>"
#     eos_token: "</s>"
#     unk_token: "<unk>"
# ```

# %%
# !pip3 install -U -qqq torch torchvision torchaudio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 84.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 52.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 85.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# xformers 0.0.22 requires torch==2.0.1, but you have torch 2.1.2 which is incompatible.

# %%
# !git clone https://github.com/OpenAccess-AI-Collective/axolotl
# Out:
# fatal: destination path 'axolotl' already exists and is not an empty directory.

# %%
# %cd axolotl
# Out:
# /content/axolotl

# %%
# !pip3 install packaging
# Out:
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (23.2)

# %%
# !pip3 install -e '.[flash-attn,deepspeed]'
# Out:
# Obtaining file:///content/axolotl
#   Preparing metadata (setup.py) ... done
# Collecting transformers@ git+https://github.com/huggingface/transformers.git@3cefac1d974db5e2825a0cb2b842883a628be7a0 (from axolotl==0.3.0)
#   Using cached transformers-4.37.0.dev0-py3-none-any.whl
# Collecting accelerate@ git+https://github.com/huggingface/accelerate.git@0d2280dadc6a93413a5496613b7fdda3a4d2551b (from axolotl==0.3.0)
#   Using cached accelerate-0.25.0.dev0-py3-none-any.whl
# Requirement already satisfied: packaging==23.2 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (23.2)
# Requirement already satisfied: peft==0.7.0 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.7.0)
# Requirement already satisfied: tokenizers==0.15.0 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.15.0)
# Requirement already satisfied: bitsandbytes>=0.41.1 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.42.0)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2.4.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.5.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (6.0.1)
# Requirement already satisfied: datasets>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2.16.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.1.99)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.16.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.7.0)
# Requirement already satisfied: xformers==0.0.22 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.0.22)
# Requirement already satisfied: optimum==1.13.2 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (1.13.2)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.1.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.4.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.58.1)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (1.26.3)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2.9.2)
# Requirement already satisfied: bert-score==0.3.13 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.3.13)
# Requirement already satisfied: evaluate==0.4.0 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.4.0)
# Requirement already satisfied: rouge-score==0.1.2 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (1.11.4)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (1.2.2)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (11.5.0)
# Requirement already satisfied: art in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (6.1)
# Requirement already satisfied: fschat==0.2.34 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.2.34)
# Requirement already satisfied: gradio==3.50.2 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (3.50.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2.15.1)
# Requirement already satisfied: s3fs in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2023.6.0)
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2023.6.0)
# Requirement already satisfied: trl>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.7.10)
# Requirement already satisfied: deepspeed in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (0.13.0)
# Requirement already satisfied: flash-attn==2.3.3 in /usr/local/lib/python3.10/dist-packages (from axolotl==0.3.0) (2.3.3)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score==0.3.13->axolotl==0.3.0) (2.1.2)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score==0.3.13->axolotl==0.3.0) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score==0.3.13->axolotl==0.3.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score==0.3.13->axolotl==0.3.0) (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score==0.3.13->axolotl==0.3.0) (3.7.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (0.20.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->axolotl==0.3.0) (0.18.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash-attn==2.3.3->axolotl==0.3.0) (1.11.1.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (3.9.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (0.109.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (0.26.0)
# Requirement already satisfied: markdown2[all] in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (2.4.12)
# Requirement already satisfied: nh3 in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (0.2.15)
# Requirement already satisfied: prompt-toolkit>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (3.0.43)
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (1.10.13)
# Requirement already satisfied: rich>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (13.7.0)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (1.0.11)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (0.5.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (from fschat==0.2.34->axolotl==0.3.0) (0.26.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (4.2.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (0.3.1)
# Requirement already satisfied: gradio-client==0.6.1 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (0.6.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (3.9.12)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (9.4.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (0.0.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (4.9.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.50.2->axolotl==0.3.0) (11.0.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from optimum==1.13.2->axolotl==0.3.0) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum==1.13.2->axolotl==0.3.0) (1.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->axolotl==0.3.0) (5.9.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->axolotl==0.3.0) (0.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->axolotl==0.3.0) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->axolotl==0.3.0) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->axolotl==0.3.0) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->axolotl==0.3.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->axolotl==0.3.0) (3.2.0)
# Collecting torch>=1.0.0 (from bert-score==0.3.13->axolotl==0.3.0)
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (3.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (11.7.91)
# Collecting triton==2.0.0 (from torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0)
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (0.42.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (3.27.9)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert-score==0.3.13->axolotl==0.3.0) (17.0.6)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.15.0->axolotl==0.3.0) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.15.0->axolotl==0.3.0) (0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers@ git+https://github.com/huggingface/transformers.git@3cefac1d974db5e2825a0cb2b842883a628be7a0->axolotl==0.3.0) (2023.6.3)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from trl>=0.7.9->axolotl==0.3.0) (0.6.6)
# Requirement already satisfied: hjson in /usr/local/lib/python3.10/dist-packages (from deepspeed->axolotl==0.3.0) (3.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed->axolotl==0.3.0) (9.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->axolotl==0.3.0) (2.4.0)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs->axolotl==0.3.0) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs->axolotl==0.3.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (from gcsfs->axolotl==0.3.0) (1.2.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from gcsfs->axolotl==0.3.0) (2.8.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (0.18.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (3.1.41)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (3.20.3)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (2023.3.post1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (7.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (1.13.1)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (6.1.3)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (2.2.5)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (2.0.24)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (3.5.2)
# Requirement already satisfied: gunicorn<22 in /usr/local/lib/python3.10/dist-packages (from mlflow->axolotl==0.3.0) (21.2.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->axolotl==0.3.0) (0.41.1)
# Requirement already satisfied: aiobotocore~=2.5.0 in /usr/local/lib/python3.10/dist-packages (from s3fs->axolotl==0.3.0) (2.5.4)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->axolotl==0.3.0) (1.60.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->axolotl==0.3.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->axolotl==0.3.0) (3.0.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->axolotl==0.3.0) (1.39.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->axolotl==0.3.0) (0.4.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->axolotl==0.3.0) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->axolotl==0.3.0) (1.4.4)
# Requirement already satisfied: botocore<1.31.18,>=1.31.17 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs->axolotl==0.3.0) (1.31.17)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs->axolotl==0.3.0) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs->axolotl==0.3.0) (0.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->fschat==0.2.34->axolotl==0.3.0) (4.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic!=1.10.0,<2->mlflow->axolotl==0.3.0) (1.3.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.50.2->axolotl==0.3.0) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.50.2->axolotl==0.3.0) (0.12.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->axolotl==0.3.0) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->axolotl==0.3.0) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->axolotl==0.3.0) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->axolotl==0.3.0) (1.26.18)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow->axolotl==0.3.0) (1.7.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow->axolotl==0.3.0) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython<4,>=2.1.0->mlflow->axolotl==0.3.0) (4.0.11)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->axolotl==0.3.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->axolotl==0.3.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->axolotl==0.3.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib->gcsfs->axolotl==0.3.0) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow->axolotl==0.3.0) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score==0.3.13->axolotl==0.3.0) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit>=3.0.0->fschat==0.2.34->axolotl==0.3.0) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score==0.3.13->axolotl==0.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score==0.3.13->axolotl==0.3.0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score==0.3.13->axolotl==0.3.0) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat==0.2.34->axolotl==0.3.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat==0.2.34->axolotl==0.3.0) (2.16.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->axolotl==0.3.0) (3.0.3)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl>=0.7.9->axolotl==0.3.0) (0.15)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl>=0.7.9->axolotl==0.3.0) (1.6.5)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->fschat==0.2.34->axolotl==0.3.0) (0.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->optimum==1.13.2->axolotl==0.3.0) (10.0)
# Requirement already satisfied: starlette<0.36.0,>=0.35.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->fschat==0.2.34->axolotl==0.3.0) (0.35.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->axolotl==0.3.0) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->axolotl==0.3.0) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->axolotl==0.3.0) (2.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->fschat==0.2.34->axolotl==0.3.0) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->fschat==0.2.34->axolotl==0.3.0) (1.0.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->fschat==0.2.34->axolotl==0.3.0) (1.3.0)
# Requirement already satisfied: wavedrom in /usr/local/lib/python3.10/dist-packages (from markdown2[all]->fschat==0.2.34->axolotl==0.3.0) (2.0.3.post3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum==1.13.2->axolotl==0.3.0) (1.3.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.31.18,>=1.31.17->aiobotocore~=2.5.0->s3fs->axolotl==0.3.0) (1.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->axolotl==0.3.0) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs->axolotl==0.3.0) (1.62.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs->axolotl==0.3.0) (1.5.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->axolotl==0.3.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->axolotl==0.3.0) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->axolotl==0.3.0) (0.17.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.0.0->fschat==0.2.34->axolotl==0.3.0) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->axolotl==0.3.0) (0.5.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->fschat==0.2.34->axolotl==0.3.0) (1.2.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.10/dist-packages (from wavedrom->markdown2[all]->fschat==0.2.34->axolotl==0.3.0) (1.4.3)
# Installing collected packages: triton, torch, axolotl
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
#       Successfully uninstalled triton-2.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: axolotl
#     Found existing installation: axolotl 0.3.0
#     Uninstalling axolotl-0.3.0:
#       Successfully uninstalled axolotl-0.3.0
#   Running setup.py develop for axolotl
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.2 requires torch==2.1.2, but you have torch 2.0.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchvision 0.16.2 requires torch==2.1.2, but you have torch 2.0.1 which is incompatible.
# Successfully installed axolotl torch-2.0.1 triton-2.0.0

# %%
# !pip3 install -U git+https://github.com/huggingface/peft.git
# Out:
# Collecting git+https://github.com/huggingface/peft.git
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-2ci0ev00
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-2ci0ev00
#   Resolved https://github.com/huggingface/peft.git to commit ebbff4023ad276cbcb2466fd7e99be7d3ae0ae11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (2.0.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (4.37.0.dev0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (4.66.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.25.0.dev0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.4.1)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.2.dev0) (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft==0.7.2.dev0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft==0.7.2.dev0) (0.42.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.7.2.dev0) (3.27.9)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.7.2.dev0) (17.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.7.2.dev0) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.7.2.dev0) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft==0.7.2.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft==0.7.2.dev0) (1.3.0)
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.7.2.dev0-py3-none-any.whl size=183138 sha256=433fbfc0deec77ab1799a7288cd5b71bfe9fe2cfc500321f4232c6e86e981e71
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0gj0pzty/wheels/d7/c7/de/1368fac8590e1b103ddc2ec2a28ad51d83aded1a3830e8a087
# Successfully built peft
# Installing collected packages: peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.7.0
#     Uninstalling peft-0.7.0:
#       Successfully uninstalled peft-0.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# axolotl 0.3.0 requires peft==0.7.0, but you have peft 0.7.2.dev0 which is incompatible.
# Successfully installed peft-0.7.2.dev0

# %%
# !pip install -U flash-attn --no-build-isolation
# Out:
# Requirement already satisfied: flash-attn in /usr/local/lib/python3.10/dist-packages (2.3.3)
# Collecting flash-attn
#   Downloading flash_attn-2.4.2.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash-attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash-attn) (23.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash-attn) (1.11.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->flash-attn) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->flash-attn) (0.42.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->flash-attn) (3.27.9)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->flash-attn) (17.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash-attn) (1.3.0)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.4.2-cp310-cp310-linux_x86_64.whl size=113930372 sha256=2c7ddc942e0715ef4a7ab62e3404b519a7ac040b3b6eae8fedcdc08a36ced786
#   Stored in directory: /root/.cache/pip/wheels/9d/cf/7f/d14555553b5b30698dae0a4159fdd058157e7021cec565ecaa
# Successfully built flash-attn
# Installing collected packages: flash-attn
#   Attempting uninstall: flash-attn
#     Found existing installation: flash-attn 2.3.3
#     Uninstalling flash-attn-2.3.3:
#       Successfully uninstalled flash-attn-2.3.3
# Successfully installed flash-attn-2.4.2

# %%
# !wget https://github.com/Skower/mlpops/blob/d676a2755426f0f94ee03a3649ba8c6c6f2d1d4e/model-finetuning/TinyLlamusk.yml
# Out:
# --2024-01-20 19:33:29--  https://github.com/Skower/mlpops/blob/d676a2755426f0f94ee03a3649ba8c6c6f2d1d4e/model-finetuning/TinyLlamusk.yml
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10995 (11K) [text/plain]
# Saving to: ‘TinyLlamusk.yml’
#
# TinyLlamusk.yml     100%[===================>]  10.74K  --.-KB/s    in 0.008s
#
# 2024-01-20 19:33:29 (1.34 MB/s) - ‘TinyLlamusk.yml’ saved [10995/10995]

# %%
# %env HUGGING_FACE_HUB_TOKEN=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
# Out:
# env: HUGGING_FACE_HUB_TOKEN=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

# %%
# %env WANDB_API_KEY=fcbdc8ae35ee4c6ccbb132cb80ec158938fb44bb
# Out:
# env: WANDB_API_KEY=fcbdc8ae35ee4c6ccbb132cb80ec158938fb44bb

# %%
# !accelerate launch -m axolotl.cli.train TinyLlamusk.yml
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2024-01-20 19:55:10.660521: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-20 19:55:10.660576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-20 19:55:10.662017: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-20 19:55:11.716659: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# [2024-01-20 19:55:13,625] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-20 19:55:25,297] [INFO] [axolotl.normalize_config:163] [PID:14019] [RANK:0] GPU memory usage baseline: 0.000GB (+0.255GB misc)
#                                  dP            dP   dP
#                                  88            88   88
#       .d8888b. dP.  .dP .d8888b. 88 .d8888b. d8888P 88
#       88'  `88  `8bd8'  88'  `88 88 88'  `88   88   88
#       88.  .88  .d88b.  88.  .88 88 88.  .88   88   88
#       `88888P8 dP'  `dP `88888P' dP `88888P'   dP   dP
#
#
#
# [2024-01-20 19:55:25,673] [DEBUG] [axolotl.load_tokenizer:210] [PID:14019] [RANK:0] EOS: 2 / </s>
# [2024-01-20 19:55:25,673] [DEBUG] [axolotl.load_tokenizer:211] [PID:14019] [RANK:0] BOS: 1 / <s>
# [2024-01-20 19:55:25,673] [DEBUG] [axolotl.load_tokenizer:212] [PID:14019] [RANK:0] PAD: 2 / </s>
# [2024-01-20 19:55:25,673] [DEBUG] [axolotl.load_tokenizer:213] [PID:14019] [RANK:0] UNK: 0 / <unk>
# [2024-01-20 19:55:25,673] [INFO] [axolotl.load_tokenizer:218] [PID:14019] [RANK:0] No Chat template selected. Consider adding a chat template for easier inference.
# [2024-01-20 19:55:25,673] [INFO] [axolotl.load_tokenized_prepared_datasets:161] [PID:14019] [RANK:0] Unable to find prepared dataset in last_run_prepared/a7a8fc2476b12b5ffcf2efde32fc7bbb
# [2024-01-20 19:55:25,673] [INFO] [axolotl.load_tokenized_prepared_datasets:162] [PID:14019] [RANK:0] Loading raw datasets...
# [2024-01-20 19:55:25,673] [WARNING] [axolotl.load_tokenized_prepared_datasets:164] [PID:14019] [RANK:0] Processing datasets during training can lead to VRAM instability. Please pre-process your dataset
# [2024-01-20 19:55:25,673] [INFO] [axolotl.load_tokenized_prepared_datasets:171] [PID:14019] [RANK:0] No seed provided, using default seed of 42
# Map (num_proc=2): 100% 1601/1601 [00:01<00:00, 1451.12 examples/s]
# [2024-01-20 19:55:29,537] [INFO] [axolotl.load_tokenized_prepared_datasets:380] [PID:14019] [RANK:0] merging datasets
# Map (num_proc=2): 100% 1601/1601 [00:00<00:00, 4599.64 examples/s]
# [2024-01-20 19:55:29,976] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] max_input_len: 119
# Filter (num_proc=2): 100% 1601/1601 [00:00<00:00, 5776.15 examples/s]
# [2024-01-20 19:55:30,327] [INFO] [axolotl.load_tokenized_prepared_datasets:390] [PID:14019] [RANK:0] Saving merged prepared dataset to disk... last_run_prepared/a7a8fc2476b12b5ffcf2efde32fc7bbb
# Saving the dataset (1/1 shards): 100% 1601/1601 [00:00<00:00, 74130.98 examples/s]
# [2024-01-20 19:55:30,359] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] total_num_tokens: 62491
# [2024-01-20 19:55:30,373] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] `total_supervised_tokens: 62491`
# [2024-01-20 19:55:36,173] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 1.0 total_num_tokens per device: 62491
# [2024-01-20 19:55:36,174] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] data_loader_len: 29
# [2024-01-20 19:55:36,174] [INFO] [axolotl.log:61] [PID:14019] [RANK:0] sample_packing_eff_est across ranks: [0.5439453125]
# [2024-01-20 19:55:36,174] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] sample_packing_eff_est: None
# [2024-01-20 19:55:36,174] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] total_num_steps: 116
# [2024-01-20 19:55:36,176] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] total_num_tokens: 62491
# [2024-01-20 19:55:36,190] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] `total_supervised_tokens: 62491`
# [2024-01-20 19:55:36,194] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 1.0 total_num_tokens per device: 62491
# [2024-01-20 19:55:36,194] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] data_loader_len: 29
# [2024-01-20 19:55:36,194] [INFO] [axolotl.log:61] [PID:14019] [RANK:0] sample_packing_eff_est across ranks: [0.9623078377016129]
# [2024-01-20 19:55:36,195] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] sample_packing_eff_est: 0.97
# [2024-01-20 19:55:36,195] [DEBUG] [axolotl.log:61] [PID:14019] [RANK:0] total_num_steps: 116
# [2024-01-20 19:55:36,195] [DEBUG] [axolotl.train.log:61] [PID:14019] [RANK:0] loading tokenizer... TinyLlama/TinyLlama-1.1B-Chat-v1.0
# [2024-01-20 19:55:36,489] [DEBUG] [axolotl.load_tokenizer:210] [PID:14019] [RANK:0] EOS: 2 / </s>
# [2024-01-20 19:55:36,489] [DEBUG] [axolotl.load_tokenizer:211] [PID:14019] [RANK:0] BOS: 1 / <s>
# [2024-01-20 19:55:36,489] [DEBUG] [axolotl.load_tokenizer:212] [PID:14019] [RANK:0] PAD: 2 / </s>
# [2024-01-20 19:55:36,489] [DEBUG] [axolotl.load_tokenizer:213] [PID:14019] [RANK:0] UNK: 0 / <unk>
# [2024-01-20 19:55:36,489] [INFO] [axolotl.load_tokenizer:218] [PID:14019] [RANK:0] No Chat template selected. Consider adding a chat template for easier inference.
# [2024-01-20 19:55:36,490] [DEBUG] [axolotl.train.log:61] [PID:14019] [RANK:0] loading model and peft_config...
# [2024-01-20 19:55:36,583] [INFO] [axolotl.load_model:335] [PID:14019] [RANK:0] patching _expand_mask
# [2024-01-20 19:55:42,377] [INFO] [axolotl.load_model:615] [PID:14019] [RANK:0] GPU memory usage after model load: 0.753GB (+0.022GB cache, +0.370GB misc)
# [2024-01-20 19:55:42,382] [INFO] [axolotl.load_model:639] [PID:14019] [RANK:0] converting PEFT model w/ prepare_model_for_kbit_training
# [2024-01-20 19:55:42,386] [INFO] [axolotl.load_model:651] [PID:14019] [RANK:0] converting modules to torch.float16 for flash attention
# [2024-01-20 19:55:42,389] [INFO] [axolotl.load_lora:756] [PID:14019] [RANK:0] found linear modules: ['v_proj', 'o_proj', 'k_proj', 'up_proj', 'down_proj', 'gate_proj', 'q_proj']
# trainable params: 25,231,360 || all params: 1,125,279,744 || trainable%: 2.2422299996542017
# [2024-01-20 19:55:42,802] [INFO] [axolotl.load_model:683] [PID:14019] [RANK:0] GPU memory usage after adapters: 0.847GB (+0.514GB cache, +0.370GB misc)
# [2024-01-20 19:55:42,899] [INFO] [axolotl.train.log:61] [PID:14019] [RANK:0] Pre-saving adapter config to ./qlora-out
# [2024-01-20 19:55:42,903] [INFO] [axolotl.train.log:61] [PID:14019] [RANK:0] Starting trainer...
# [2024-01-20 19:55:43,340] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:55:43,341] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# wandb: Currently logged in as: bastien-pouessel. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in /content/axolotl/wandb/run-20240120_195544-m8xt554i
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run warm-music-2
# wandb: ⭐️ View project at https://wandb.ai/bastien-pouessel/axolotl-tinyllama
# wandb: 🚀 View run at https://wandb.ai/bastien-pouessel/axolotl-tinyllama/runs/m8xt554i
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# [2024-01-20 19:55:44,980] [INFO] [axolotl.callbacks.on_train_begin:572] [PID:14019] [RANK:0] The Axolotl config has been saved to the WandB run under files.
#   0% 0/60 [00:00<?, ?it/s][2024-01-20 19:55:44,983] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# {'loss': 6.8915, 'learning_rate': 2e-05, 'epoch': 0.07}
#   2% 1/60 [00:04<04:40,  4.76s/it][2024-01-20 19:55:49,742] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:55:50,133] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:55:50,134] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 6.548497200012207, 'eval_runtime': 0.6195, 'eval_samples_per_second': 53.271, 'eval_steps_per_second': 53.271, 'epoch': 0.07}
#   2% 1/60 [00:05<04:40,  4.76s/it]
#   3% 1/30 [00:00<00:06,  4.39it/s]
#                                   [2024-01-20 19:55:54,649] [INFO] [axolotl.callbacks.on_step_end:124] [PID:14019] [RANK:0] GPU memory usage while training: 0.963GB (+3.725GB cache, +0.640GB misc)
# {'loss': 7.0514, 'learning_rate': 4e-05, 'epoch': 0.13}
# {'loss': 6.9728, 'learning_rate': 6e-05, 'epoch': 0.2}
# {'loss': 6.723, 'learning_rate': 8e-05, 'epoch': 0.27}
# {'loss': 6.7751, 'learning_rate': 0.0001, 'epoch': 0.33}
# {'loss': 6.6997, 'learning_rate': 0.00012, 'epoch': 0.4}
# {'loss': 6.3633, 'learning_rate': 0.00014, 'epoch': 0.47}
# {'loss': 6.1595, 'learning_rate': 0.00016, 'epoch': 0.53}
#  13% 8/60 [00:35<03:45,  4.34s/it][2024-01-20 19:56:20,458] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:56:20,862] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:56:20,863] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 5.870787143707275, 'eval_runtime': 0.6447, 'eval_samples_per_second': 51.185, 'eval_steps_per_second': 51.185, 'epoch': 0.53}
#  13% 8/60 [00:36<03:45,  4.34s/it]
#   3% 1/30 [00:00<00:07,  4.10it/s]
# {'loss': 6.0649, 'learning_rate': 0.00018, 'epoch': 0.6}
# {'loss': 5.8986, 'learning_rate': 0.0002, 'epoch': 0.67}
# {'loss': 5.6976, 'learning_rate': 0.00019980267284282717, 'epoch': 0.73}
# {'loss': 5.5865, 'learning_rate': 0.0001992114701314478, 'epoch': 0.8}
# {'loss': 5.573, 'learning_rate': 0.0001982287250728689, 'epoch': 0.87}
# {'loss': 5.4152, 'learning_rate': 0.0001968583161128631, 'epoch': 0.93}
# {'loss': 5.3824, 'learning_rate': 0.00019510565162951537, 'epoch': 1.0}
#  25% 15/60 [01:06<03:17,  4.39s/it][2024-01-20 19:56:59,903] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# {'loss': 5.361, 'learning_rate': 0.00019297764858882514, 'epoch': 1.03}
#  27% 16/60 [01:17<04:36,  6.27s/it][2024-01-20 19:57:02,270] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:57:02,679] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:57:02,681] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 5.297865390777588, 'eval_runtime': 0.6544, 'eval_samples_per_second': 50.425, 'eval_steps_per_second': 50.425, 'epoch': 1.03}
#  27% 16/60 [01:17<04:36,  6.27s/it]
#   3% 1/30 [00:00<00:07,  4.01it/s]
# {'loss': 5.3028, 'learning_rate': 0.00019048270524660196, 'epoch': 1.1}
# {'loss': 5.1177, 'learning_rate': 0.00018763066800438636, 'epoch': 1.17}
# {'loss': 5.1562, 'learning_rate': 0.00018443279255020152, 'epoch': 1.23}
# {'loss': 5.1792, 'learning_rate': 0.00018090169943749476, 'epoch': 1.3}
# {'loss': 5.0329, 'learning_rate': 0.00017705132427757895, 'epoch': 1.37}
# {'loss': 5.0162, 'learning_rate': 0.00017289686274214118, 'epoch': 1.43}
# {'loss': 5.0403, 'learning_rate': 0.00016845471059286887, 'epoch': 1.5}
# {'loss': 4.8874, 'learning_rate': 0.000163742398974869, 'epoch': 1.57}
#  40% 24/60 [01:53<02:44,  4.58s/it][2024-01-20 19:57:38,462] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:57:38,871] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:57:38,872] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 5.049340724945068, 'eval_runtime': 0.6616, 'eval_samples_per_second': 49.882, 'eval_steps_per_second': 49.882, 'epoch': 1.57}
#  40% 24/60 [01:54<02:44,  4.58s/it]
#   3% 1/30 [00:00<00:07,  3.97it/s]
# {'loss': 4.963, 'learning_rate': 0.00015877852522924732, 'epoch': 1.63}
# {'loss': 4.8614, 'learning_rate': 0.00015358267949789966, 'epoch': 1.7}
# {'loss': 4.8328, 'learning_rate': 0.00014817536741017152, 'epoch': 1.77}
# {'loss': 4.6908, 'learning_rate': 0.00014257792915650728, 'epoch': 1.83}
# {'loss': 4.8507, 'learning_rate': 0.00013681245526846783, 'epoch': 1.9}
# {'loss': 4.7673, 'learning_rate': 0.00013090169943749476, 'epoch': 1.97}
# {'loss': 4.6783, 'learning_rate': 0.0001248689887164855, 'epoch': 2.03}
#  52% 31/60 [02:27<02:27,  5.10s/it][2024-01-20 19:58:12,659] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# {'loss': 4.7517, 'learning_rate': 0.00011873813145857249, 'epoch': 2.07}
#  53% 32/60 [02:32<02:18,  4.95s/it][2024-01-20 19:58:17,259] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:58:17,676] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:58:17,677] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 4.930439472198486, 'eval_runtime': 0.6774, 'eval_samples_per_second': 48.718, 'eval_steps_per_second': 48.718, 'epoch': 2.07}
#  53% 32/60 [02:32<02:18,  4.95s/it]
#   3% 1/30 [00:00<00:07,  3.83it/s]
# {'loss': 4.7078, 'learning_rate': 0.00011253332335643043, 'epoch': 2.13}
# {'loss': 4.7558, 'learning_rate': 0.00010627905195293135, 'epoch': 2.2}
# {'loss': 4.6508, 'learning_rate': 0.0001, 'epoch': 2.27}
# {'loss': 4.6559, 'learning_rate': 9.372094804706867e-05, 'epoch': 2.33}
# {'loss': 4.6233, 'learning_rate': 8.746667664356956e-05, 'epoch': 2.4}
# {'loss': 4.5974, 'learning_rate': 8.126186854142752e-05, 'epoch': 2.47}
# {'loss': 4.594, 'learning_rate': 7.513101128351454e-05, 'epoch': 2.53}
# {'loss': 4.6544, 'learning_rate': 6.909830056250527e-05, 'epoch': 2.6}
#  67% 40/60 [03:10<01:33,  4.66s/it][2024-01-20 19:58:55,086] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:58:55,505] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:58:55,506] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 4.845010757446289, 'eval_runtime': 0.6801, 'eval_samples_per_second': 48.522, 'eval_steps_per_second': 48.522, 'epoch': 2.6}
#  67% 40/60 [03:10<01:33,  4.66s/it]
#   3% 1/30 [00:00<00:07,  3.84it/s]
# {'loss': 4.4748, 'learning_rate': 6.318754473153221e-05, 'epoch': 2.67}
# {'loss': 4.4752, 'learning_rate': 5.7422070843492734e-05, 'epoch': 2.73}
# {'loss': 4.6213, 'learning_rate': 5.182463258982846e-05, 'epoch': 2.8}
# {'loss': 4.5016, 'learning_rate': 4.6417320502100316e-05, 'epoch': 2.87}
# {'loss': 4.441, 'learning_rate': 4.12214747707527e-05, 'epoch': 2.93}
# {'loss': 4.4973, 'learning_rate': 3.6257601025131026e-05, 'epoch': 3.0}
#  77% 46/60 [03:40<01:12,  5.21s/it][2024-01-20 19:59:27,510] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# {'loss': 4.1134, 'learning_rate': 3.154528940713113e-05, 'epoch': 3.03}
# {'loss': 4.544, 'learning_rate': 2.7103137257858868e-05, 'epoch': 3.1}
#  80% 48/60 [03:49<00:58,  4.89s/it][2024-01-20 19:59:34,476] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:59:34,890] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 19:59:34,891] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 4.7767333984375, 'eval_runtime': 0.6754, 'eval_samples_per_second': 48.856, 'eval_steps_per_second': 48.856, 'epoch': 3.1}
#  80% 48/60 [03:50<00:58,  4.89s/it]
#   3% 1/30 [00:00<00:07,  3.82it/s]
# {'loss': 4.4459, 'learning_rate': 2.2948675722421086e-05, 'epoch': 3.17}
# {'loss': 4.4709, 'learning_rate': 1.9098300562505266e-05, 'epoch': 3.23}
# {'loss': 4.4321, 'learning_rate': 1.5567207449798515e-05, 'epoch': 3.3}
# {'loss': 4.5346, 'learning_rate': 1.2369331995613665e-05, 'epoch': 3.37}
# {'loss': 4.4476, 'learning_rate': 9.517294753398064e-06, 'epoch': 3.43}
# {'loss': 4.441, 'learning_rate': 7.022351411174866e-06, 'epoch': 3.5}
# {'loss': 4.5312, 'learning_rate': 4.8943483704846475e-06, 'epoch': 3.57}
# {'loss': 4.4482, 'learning_rate': 3.1416838871368924e-06, 'epoch': 3.63}
#  93% 56/60 [04:27<00:18,  4.67s/it][2024-01-20 20:00:12,232] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 20:00:12,648] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
# [2024-01-20 20:00:12,649] [INFO] [axolotl.utils.samplers.multipack._len_est:178] [PID:14019] [RANK:0] packing_efficiency_estimate: 0.97 total_num_tokens per device: 62491
#
#
# {'eval_loss': 4.758652687072754, 'eval_runtime': 0.6784, 'eval_samples_per_second': 48.644, 'eval_steps_per_second': 48.644, 'epoch': 3.63}
#  93% 56/60 [04:27<00:18,  4.67s/it]
#   3% 1/30 [00:00<00:07,  3.81it/s]
# {'loss': 4.4258, 'learning_rate': 1.771274927131139e-06, 'epoch': 3.7}
# {'loss': 4.4914, 'learning_rate': 7.885298685522235e-07, 'epoch': 3.77}
# {'loss': 4.444, 'learning_rate': 1.973271571728441e-07, 'epoch': 3.83}
# {'loss': 4.3851, 'learning_rate': 0.0, 'epoch': 3.9}
# {'train_runtime': 289.5163, 'train_samples_per_second': 21.664, 'train_steps_per_second': 0.207, 'train_loss': 5.069164816538493, 'epoch': 3.9}
# 100% 60/60 [04:47<00:00,  4.80s/it]
# [2024-01-20 20:00:37,191] [INFO] [axolotl.train.log:61] [PID:14019] [RANK:0] Training Completed!!! Saving pre-trained model to ./qlora-out
# adapter_model.bin: 100% 101M/101M [00:05<00:00, 19.3MB/s]
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb: Run history:
# wandb:                      eval/loss █▅▃▂▂▁▁▁
# wandb:                   eval/runtime ▁▄▅▆██▇█
# wandb:        eval/samples_per_second █▅▄▃▁▁▁▁
# wandb:          eval/steps_per_second █▅▄▃▁▁▁▁
# wandb:                    train/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████
# wandb:              train/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:            train/learning_rate ▂▂▄▅▆▇██████▇▇▇▇▇▆▆▆▅▅▅▅▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁
# wandb:                     train/loss ██▇▇▆▆▅▅▄▄▄▄▃▄▃▃▃▃▂▃▂▃▃▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂
# wandb:               train/total_flos ▁
# wandb:               train/train_loss ▁
# wandb:            train/train_runtime ▁
# wandb: train/train_samples_per_second ▁
# wandb:   train/train_steps_per_second ▁
# wandb:
# wandb: Run summary:
# wandb:                      eval/loss 4.75865
# wandb:                   eval/runtime 0.6784
# wandb:        eval/samples_per_second 48.644
# wandb:          eval/steps_per_second 48.644
# wandb:                    train/epoch 3.9
# wandb:              train/global_step 60
# wandb:            train/learning_rate 0.0
# wandb:                     train/loss 4.3851
# wandb:               train/total_flos 1562655735152640.0
# wandb:               train/train_loss 5.06916
# wandb:            train/train_runtime 289.5163
# wandb: train/train_samples_per_second 21.664
# wandb:   train/train_steps_per_second 0.207
# wandb:
# wandb: 🚀 View run warm-music-2 at: https://wandb.ai/bastien-pouessel/axolotl-tinyllama/runs/m8xt554i
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./wandb/run-20240120_195544-m8xt554i/logs

# %%
# !wget https://gist.githubusercontent.com/mlabonne/a3542b0519708b8871d0703c938bba9f/raw/60abc5afc07f9d843bc23d56f4e0b7ab072c4a62/merge_peft.py
# Out:
# --2024-01-20 20:02:18--  https://gist.githubusercontent.com/mlabonne/a3542b0519708b8871d0703c938bba9f/raw/60abc5afc07f9d843bc23d56f4e0b7ab072c4a62/merge_peft.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1502 (1.5K) [text/plain]
# Saving to: ‘merge_peft.py’
#
# merge_peft.py       100%[===================>]   1.47K  --.-KB/s    in 0s
#
# 2024-01-20 20:02:18 (27.8 MB/s) - ‘merge_peft.py’ saved [1502/1502]

# %%
# !python merge_peft.py --base_model=TinyLlama/TinyLlama-1.1B-Chat-v1.0 --peft_model=./qlora-out --hub_id=TinyLlamusk
# Out:
# [1/5] Loading base model: TinyLlama/TinyLlama-1.1B-Chat-v1.0
# [2/5] Loading adapter: ./qlora-out
# [3/5] Merge base model and adapter
# [4/5] Saving model and tokenizer in TinyLlamusk
# [5/5] Uploading to Hugging Face Hub: TinyLlamusk
# model.safetensors: 100% 2.20G/2.20G [00:57<00:00, 38.0MB/s]
# Merged model uploaded to Hugging Face Hub!
